# %% [markdown]
# # Initialize

# %%
# %cd "/leonardo_scratch/fast/INF25_pml4hep/sgrossi0/projects/TwoSampleTest/NPLM_Parameters_Tuning"
# Out:
# /leonardo_scratch/fast/INF25_pml4hep/sgrossi0/projects/TwoSampleTest/NPLM_Parameters_Tuning
# /leonardo_scratch/fast/INF25_pml4hep/envs/tf2_custom_torch2.2/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
visible_devices = [1]
from datetime import datetime
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing os...")
import os
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing sys...")
import sys
if not any("ipykernel" in arg for arg in sys.argv):
    print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing and initializing argparse...")
    import argparse
    parser = argparse.ArgumentParser()
    parser.add_argument("-v", "--visible_devices", help="Set visible devices", nargs='*', type=list, default=visible_devices)
    args = parser.parse_args()
    visible_devices = args.visible_devices if args.visible_devices else visible_devices
    if not isinstance(visible_devices, list):
        raise ValueError("Visible devices must be a list of integers")
    for i in visible_devices:
        if not isinstance(i, int):
            raise ValueError("Visible devices must be a list of integers")
print("Visible devices:", visible_devices)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timer from timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting env variables for tf import (only device(s)", visible_devices, "will be available)...")
os.environ["CUDA_VISIBLE_DEVICES"] = ','.join([str(i) for i in visible_devices]) # type: ignore
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_auto_jit=2'
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing numpy...")
import numpy as np # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing matplotlib...")
from matplotlib import pyplot as plt
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing h5py...")
import h5py # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing importlib.util...")
import importlib.util
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing json...")
import json
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing pandas...")
import pandas as pd
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing random...")
import random
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing scipy utils...")
from scipy.stats import norm, lognorm, chi2, kstwo, kstwobign, ks_2samp, moment
from scipy.special import kolmogorov
from scipy.optimize import minimize, curve_fit, root, bisect
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing subprocess...")
import subprocess
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow...")
import tensorflow as tf # type: ignore
print("Tensorflow version:", tf.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow_probability...")
import tensorflow_probability as tfp # type: ignore
tfd = tfp.distributions
print("Tensorflow probability version:", tfp.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tqdm...")
from tqdm import tqdm
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing typing...")
from typing import List, Tuple, Dict, Callable, Union, Optional, Any, Type
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting tf configs...")
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
for gpu_device in gpu_devices:
    tf.config.experimental.set_memory_growth(gpu_device, True)

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing GMetrics module...")

import GMetrics # type: ignore
from GMetrics.metrics.NPLM import candidate_sigma
from GMetrics.plotters import plot_corners, cornerplotter, plot_corr_matrix, plot_corr_matrix_side_by_side # type: ignore
from GMetrics.more import MixtureDistributions # type: ignore
from GMetrics.more import deformations # type: ignore
from GMetrics.more.optimizers_deformations import compute_exclusion_bisection, compute_exclusion_bisection_np ,compute_exclusion_LR_bisection # type: ignore
from GMetrics.utils import se_mean, se_std

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing jetnet.evaluation.gen_metrics module...")
from jetnet.evaluation import gen_metrics as JMetrics # type: ignore

def get_gpu_info():
    try:
        gpu_info = subprocess.check_output(["nvidia-smi", "--query-gpu=gpu_name", "--format=csv,noheader"]).decode('utf-8')
        return gpu_info.strip().split('\n')
    except Exception as e:
        print(e)
        return None
training_devices = []
gpu_models = get_gpu_info()
for i in visible_devices:
    if gpu_models:
        training_devices.append(gpu_models[i])
        print(f"Successfully loaded GPU #{i}, model: {gpu_models[i]}")
    else:
        training_devices.append('undetermined')
        print(f"Failed to load GPU {i} model. Defaulting to 'undetermined'.")
print(f"Loaded {len(training_devices)} GPUs: {training_devices}")
    
results_dir = "results/20D_unimodal/"
if os.path.exists(results_dir):
    print("Model directory exists")
else:
    os.makedirs(results_dir)
    print("Model directory was created")
    
    
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "All done.")
# Out:
# 2025-03-01 15:15:22.053688: Importing os...
# 2025-03-01 15:15:22.053951: Importing sys...
# Visible devices: [1]
# 2025-03-01 15:15:22.054195: Importing timer from timeit...
# 2025-03-01 15:15:22.054265: Setting env variables for tf import (only device(s) [1] will be available)...
# 2025-03-01 15:15:22.054389: Importing numpy...
# 2025-03-01 15:15:22.158065: Importing matplotlib...
# 2025-03-01 15:15:22.507329: Importing h5py...
# 2025-03-01 15:15:22.538564: Importing importlib.util...
# 2025-03-01 15:15:22.538667: Importing json...
# 2025-03-01 15:15:22.538729: Importing pandas...
# 2025-03-01 15:15:22.960337: Importing random...
# 2025-03-01 15:15:22.960477: Importing scipy utils...
# 2025-03-01 15:15:23.435367: Importing subprocess...
# 2025-03-01 15:15:23.435507: Importing tensorflow...
# Tensorflow version: 2.16.1
# 2025-03-01 15:15:26.845438: Importing tensorflow_probability...
# Tensorflow probability version: 0.24.0
# 2025-03-01 15:15:27.970332: Importing timeit...
# 2025-03-01 15:15:27.970425: Importing tqdm...
# 2025-03-01 15:15:27.977874: Importing typing...
# 2025-03-01 15:15:27.977987: Setting tf configs...
# 2025-03-01 15:15:28.049259: Importing GMetrics module...
# /leonardo_scratch/fast/INF25_pml4hep/envs/tf2_custom_torch2.2/lib/python3.11/site-packages/jetnet/utils/utils.py:7: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# 2025-03-01 15:15:33.666676: Importing jetnet.evaluation.gen_metrics module...
# Successfully loaded GPU #1, model: NVIDIA A100-SXM-64GB
# Loaded 1 GPUs: ['NVIDIA A100-SXM-64GB']
# Model directory exists
# 2025-03-01 15:15:33.697675: All done.

# %% [markdown]
# # Model definition

# %%
seed = 0
ncomp = 5
ndims = 20
niter = 20
dist_1 = MixtureDistributions.MultiNormalFromMix(ncomp = ncomp,
                                                 ndims = ndims,
                                                 loc_factor = 5.,
                                                 scale_factor = 1.,
                                                 dtype = tf.float64,
                                                 seed = seed)
dist_2 = MixtureDistributions.MultiNormalFromMix(ncomp = ncomp,
                                                 ndims = ndims,
                                                 loc_factor = 5.,
                                                 scale_factor = 1.,
                                                 dtype = tf.float64,
                                                 seed = seed)
print(dist_1.dtype, dist_2.dtype)
print('Types of distributions: ', type(dist_1), type(dist_2))
print('Dtypes of distributions: ', dist_1.dtype, dist_2.dtype)
print('Batch shapes of distributions: ', dist_1.batch_shape, dist_2.batch_shape)
print('Event shapes of distributions: ', dist_1.event_shape, dist_2.event_shape)
GMetrics.utils.reset_random_seeds(seed)
print('sample from dist_1: ', dist_1.sample(2))
GMetrics.utils.reset_random_seeds(seed)
print('sample from dist_2: ', dist_2.sample(2))
# Out:
# <dtype: 'float64'> <dtype: 'float64'>
# Types of distributions:  <class 'tensorflow_probability.python.distributions.mvn_tril.MultivariateNormalTriL'> <class 'tensorflow_probability.python.distributions.mvn_tril.MultivariateNormalTriL'>
# Dtypes of distributions:  <dtype: 'float64'> <dtype: 'float64'>
# Batch shapes of distributions:  () ()
# Event shapes of distributions:  (20,) (20,)
# sample from dist_1:  tf.Tensor(
# [[ 1.62246227 -1.12148208 -3.44534996  4.02194848  1.78776681  0.88094347
#   -0.50568928 -0.93258241  0.96072818  3.18398396 -3.42493274  3.36118865
#   -0.97008955 -3.80922336 -0.88678123 -1.74309765  1.4275693  -0.80163333
#    0.77207225 -1.33233507]
#  [-0.90576152 -2.92629119  0.09540144  3.39476591 -0.96077947  2.45882417
#    1.71000076 -2.53187845 -3.05469271  1.09331411 -3.54069629  3.61418597
#   -1.99533712 -6.54250726  1.51932671 -1.73641701 -0.51890038 -3.80921806
#    2.25758194 -0.7973361 ]], shape=(2, 20), dtype=float64)
# sample from dist_2:  tf.Tensor(
# [[ 1.62246227 -1.12148208 -3.44534996  4.02194848  1.78776681  0.88094347
#   -0.50568928 -0.93258241  0.96072818  3.18398396 -3.42493274  3.36118865
#   -0.97008955 -3.80922336 -0.88678123 -1.74309765  1.4275693  -0.80163333
#    0.77207225 -1.33233507]
#  [-0.90576152 -2.92629119  0.09540144  3.39476591 -0.96077947  2.45882417
#    1.71000076 -2.53187845 -3.05469271  1.09331411 -3.54069629  3.61418597
#   -1.99533712 -6.54250726  1.51932671 -1.73641701 -0.51890038 -3.80921806
#    2.25758194 -0.7973361 ]], shape=(2, 20), dtype=float64)

# %% [markdown]
# # Fixed $n=m=20000$

# %% [markdown]
# ## Null hypothesis

# %% [markdown]
# ### Model definition

# %%
batch_size_test = 20000

# %%
model_dir = results_dir + str(ndims) + "D_" + str(int(batch_size_test/1000)) + "K_NPLM_Par/"
if os.path.exists(model_dir):
    print("Model directory exists")
else:
    os.makedirs(model_dir)
    print("Model directory was created")
    
null_hypotheses_dir = model_dir + "null_hypothesis/"
if os.path.exists(null_hypotheses_dir):
    print("Null hypothesis directory exists")
else:
    os.makedirs(null_hypotheses_dir)
    print("Null hypothesis directory was created")
# Out:
# Model directory was created
# Null hypothesis directory was created

# %%
TwoSampleTestInputs = GMetrics.TwoSampleTestInputs(dist_1_input = dist_1,
                                                   dist_2_input = dist_2,
                                                   niter = niter,
                                                   batch_size_test = batch_size_test,
                                                   batch_size_gen = 10000,
                                                   small_sample_threshold = 1e7,
                                                   dtype_input = tf.float64,
                                                   seed_input = 0,
                                                   use_tf = False,
                                                   mirror_strategy = False,
                                                   verbose = True)
print("nsamples",TwoSampleTestInputs.nsamples)
print("batch_size",TwoSampleTestInputs.batch_size_test)
print("niter",TwoSampleTestInputs.niter)
print("niter * batch_size",TwoSampleTestInputs.niter*TwoSampleTestInputs.batch_size_test)
print("small_sample",TwoSampleTestInputs.small_sample)
# Out:
# Using numpy mode with TensorFlow inputs.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Using numpy mode with TensorFlow inputs.
# Parsing input distribution...
# Input distribution is a tfp.distributions.Distribution object.
# Generating dist_1_num and dist_2_num with tensorflow function.
# Checking and setting numerical distributions.
# Setting dist_num from dist_symb.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1740838536.687279  147047 service.cc:145] XLA service 0x10c02ce40 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1740838536.687324  147047 service.cc:153]   StreamExecutor device (0): NVIDIA A100-SXM-64GB, Compute Capability 8.0
# Setting dist_num from dist_symb.
# nsamples 400000
# batch_size 20000
# niter 20
# niter * batch_size 400000
# small_sample True
# I0000 00:00:1740838539.096981  147047 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.

# %%
flk_sigma = candidate_sigma(dist_1, perc = 90)
# Out:
# Known distribution case. The distribution is the costum made MultiNormalFromMix.
# The gaussian kernel sigma is estimated as the 90th percentile of the pairwise distance among 10000 points extracted from the reference distribution.
# The value of sigma is: 21.8

# %% [markdown]
# ## Lambda Times

# %%
lam_list = [1e-5, 1e-6, 1e-7, 1e-8, 1e-9, 1e-10]

nplm_objects = {}

for i, lam in enumerate(lam_list):
    nplm_objects[f"NPLMMetric_{i}"] = GMetrics.NPLMMetric(TwoSampleTestInputs,
                                      progress_bar = True,
                                      verbose = True,
                                      M = 2000, 
                                      lam = lam, 
                                      iter_list = 1000000,
                                      flk_sigma = flk_sigma,
                                      weight = 1)
    print(f"lam value for NPLMMetric_{i} is: {nplm_objects[f'NPLMMetric_{i}'].nplm_kwargs.get('lam')}")

print(nplm_objects)
# Out:
# lam value for NPLMMetric_0 is: 1e-05
# lam value for NPLMMetric_1 is: 1e-06
# lam value for NPLMMetric_2 is: 1e-07
# lam value for NPLMMetric_3 is: 1e-08
# lam value for NPLMMetric_4 is: 1e-09
# lam value for NPLMMetric_5 is: 1e-10
# {'NPLMMetric_0': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdcf00d2010>, 'NPLMMetric_1': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdcf4ae3850>, 'NPLMMetric_2': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdcf00e6a10>, 'NPLMMetric_3': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdcf497f510>, 'NPLMMetric_4': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdcf497fa90>, 'NPLMMetric_5': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdcf497eb10>}

# %%
name = "nplm"

file = null_hypotheses_dir + f"Computing_time_vs_lambda.json"

if os.path.exists(file):
    print(f"File {file} already exists. Loading existing results.")
    with open(file, "r") as f:
        results = json.load(f)
    lam_list = [entry["lambda"] for entry in results]
    lam_list = np.array(lam_list)
    null_hp_times = [entry["computing_time"] for entry in results]
    null_hp_times = np.array(null_hp_times)
    metric_values = [entry["metric_list"] for entry in results]
    metric_values = np.array(metric_values)

    for i in range(len(lam_list)):
        print(f"For lambda = {lam_list[i]}, the null hypothesis for {niter} points has been calculated in {null_hp_times[i]} s.")

else:
    results = []
    metric_values = np.zeros((len(lam_list), niter))
    null_hp_times = np.zeros(len(lam_list))  

    for i in range(len(lam_list)):
        start = timer()
        print(f"Computing and saving {name}")
        nplm_objects[f"NPLMMetric_{i}"].Test_np()
        metric_values[i] = nplm_objects[f"NPLMMetric_{i}"].test_statistics_values
        end = timer()

        print(f"All done in: {end - start:.2f} s.")
        null_hp_times[i] = end - start  
        results.append({"lambda": lam_list[i], "computing_time": null_hp_times[i], "metric_list": metric_values[i].tolist()})

    with open(file, "w") as file:
        json.dump(results, file, indent=4)
# Out:
# File results/20D_unimodal/20D_20K_NPLM_Par/null_hypothesis/Computing_time_vs_lambda.json already exists. Loading existing results.
# For lambda = 1e-05, the null hypothesis for 20 points has been calculated in 26.36341472156346 s.
# For lambda = 1e-06, the null hypothesis for 20 points has been calculated in 31.279556774534285 s.
# For lambda = 1e-07, the null hypothesis for 20 points has been calculated in 48.254089436493814 s.
# For lambda = 1e-08, the null hypothesis for 20 points has been calculated in 86.16215994115919 s.
# For lambda = 1e-09, the null hypothesis for 20 points has been calculated in 184.38424974493682 s.
# For lambda = 1e-10, the null hypothesis for 20 points has been calculated in 434.7806728258729 s.

# %%
file = null_hypotheses_dir + f"Computing_time_vs_lambda.json"

if os.path.exists(file):
    print(f"File {file} already exists. Loading existing results.")
    with open(file, "r") as f:
        results = json.load(f)
    lam_list = [entry["lambda"] for entry in results]
    lam_list = np.array(lam_list)
    null_hp_times = [entry["computing_time"] for entry in results]
    null_hp_times = np.array(null_hp_times)
    metric_values = [entry["metric_list"] for entry in results]
    metric_values = np.array(metric_values)

else:
    print("The files does not exists.")

null_hp_times_per_point = null_hp_times/niter
print(null_hp_times_per_point)

plt.figure(figsize=(11, 6))
plt.plot(lam_list, null_hp_times_per_point, marker='o', linestyle='-', color = 'b')

plt.xscale('log')  
plt.xlabel("λ", fontsize=14)
plt.ylabel("Computing Time Per Point (s)", fontsize=14)
plt.title(f"Computing Time Per Point vs λ ({niter} points considered for H_0), fixed M = 2000", fontsize=16)
plt.grid(True, which="both", linestyle="--", linewidth=0.5)
plt.tight_layout()
plt.legend()

plt.gca().invert_xaxis()

plt.savefig(null_hypotheses_dir+"Computing_time_vs_lambda.pdf", format="pdf")
plt.show()
# Out:
# File results/20D_unimodal/20D_20K_NPLM_Par/null_hypothesis/Computing_time_vs_lambda.json already exists. Loading existing results.
# [ 1.31817074  1.56397784  2.41270447  4.308108    9.21921249 21.73903364]
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## Plot both M and lambda to see test statistic fluctuations

# %%
lam_list = [1e-6, 1e-7, 1e-8]
M_list = [500, 750, 1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 11000, 12000, 13000, 14000, 15000, 16000, 17000, 18000, 19000, 20000]

nplm_objects_M_lam = {}

for i, lam_value in enumerate(lam_list):
    for j, M_value in enumerate(M_list):
        nplm_objects_M_lam[f"NPLMMetric_{i,j}"] = GMetrics.NPLMMetric(TwoSampleTestInputs,
                                                progress_bar = True,
                                                verbose = True,
                                                M = M_value, 
                                                lam = lam_value, 
                                                iter_list = 1000000,
                                                flk_sigma = flk_sigma,
                                                weight = 1)
        print(f"(M,lam) values for NPLMMetric_{i,j} are: ({nplm_objects_M_lam[f'NPLMMetric_{i,j}'].nplm_kwargs.get('M')},{nplm_objects_M_lam[f'NPLMMetric_{i,j}'].nplm_kwargs.get('lam')})")

print(nplm_objects_M_lam)
# Out:
# (M,lam) values for NPLMMetric_(0, 0) are: (500,1e-06)
# (M,lam) values for NPLMMetric_(0, 1) are: (750,1e-06)
# (M,lam) values for NPLMMetric_(0, 2) are: (1000,1e-06)
# (M,lam) values for NPLMMetric_(0, 3) are: (2000,1e-06)
# (M,lam) values for NPLMMetric_(0, 4) are: (3000,1e-06)
# (M,lam) values for NPLMMetric_(0, 5) are: (4000,1e-06)
# (M,lam) values for NPLMMetric_(0, 6) are: (5000,1e-06)
# (M,lam) values for NPLMMetric_(0, 7) are: (6000,1e-06)
# (M,lam) values for NPLMMetric_(0, 8) are: (7000,1e-06)
# (M,lam) values for NPLMMetric_(0, 9) are: (8000,1e-06)
# (M,lam) values for NPLMMetric_(0, 10) are: (9000,1e-06)
# (M,lam) values for NPLMMetric_(0, 11) are: (10000,1e-06)
# (M,lam) values for NPLMMetric_(0, 12) are: (11000,1e-06)
# (M,lam) values for NPLMMetric_(0, 13) are: (12000,1e-06)
# (M,lam) values for NPLMMetric_(0, 14) are: (13000,1e-06)
# (M,lam) values for NPLMMetric_(0, 15) are: (14000,1e-06)
# (M,lam) values for NPLMMetric_(0, 16) are: (15000,1e-06)
# (M,lam) values for NPLMMetric_(0, 17) are: (16000,1e-06)
# (M,lam) values for NPLMMetric_(0, 18) are: (17000,1e-06)
# (M,lam) values for NPLMMetric_(0, 19) are: (18000,1e-06)
# (M,lam) values for NPLMMetric_(0, 20) are: (19000,1e-06)
# (M,lam) values for NPLMMetric_(0, 21) are: (20000,1e-06)
# (M,lam) values for NPLMMetric_(1, 0) are: (500,1e-07)
# (M,lam) values for NPLMMetric_(1, 1) are: (750,1e-07)
# (M,lam) values for NPLMMetric_(1, 2) are: (1000,1e-07)
# (M,lam) values for NPLMMetric_(1, 3) are: (2000,1e-07)
# (M,lam) values for NPLMMetric_(1, 4) are: (3000,1e-07)
# (M,lam) values for NPLMMetric_(1, 5) are: (4000,1e-07)
# (M,lam) values for NPLMMetric_(1, 6) are: (5000,1e-07)
# (M,lam) values for NPLMMetric_(1, 7) are: (6000,1e-07)
# (M,lam) values for NPLMMetric_(1, 8) are: (7000,1e-07)
# (M,lam) values for NPLMMetric_(1, 9) are: (8000,1e-07)
# (M,lam) values for NPLMMetric_(1, 10) are: (9000,1e-07)
# (M,lam) values for NPLMMetric_(1, 11) are: (10000,1e-07)
# (M,lam) values for NPLMMetric_(1, 12) are: (11000,1e-07)
# (M,lam) values for NPLMMetric_(1, 13) are: (12000,1e-07)
# (M,lam) values for NPLMMetric_(1, 14) are: (13000,1e-07)
# (M,lam) values for NPLMMetric_(1, 15) are: (14000,1e-07)
# (M,lam) values for NPLMMetric_(1, 16) are: (15000,1e-07)
# (M,lam) values for NPLMMetric_(1, 17) are: (16000,1e-07)
# (M,lam) values for NPLMMetric_(1, 18) are: (17000,1e-07)
# (M,lam) values for NPLMMetric_(1, 19) are: (18000,1e-07)
# (M,lam) values for NPLMMetric_(1, 20) are: (19000,1e-07)
# (M,lam) values for NPLMMetric_(1, 21) are: (20000,1e-07)
# (M,lam) values for NPLMMetric_(2, 0) are: (500,1e-08)
# (M,lam) values for NPLMMetric_(2, 1) are: (750,1e-08)
# (M,lam) values for NPLMMetric_(2, 2) are: (1000,1e-08)
# (M,lam) values for NPLMMetric_(2, 3) are: (2000,1e-08)
# (M,lam) values for NPLMMetric_(2, 4) are: (3000,1e-08)
# (M,lam) values for NPLMMetric_(2, 5) are: (4000,1e-08)
# (M,lam) values for NPLMMetric_(2, 6) are: (5000,1e-08)
# (M,lam) values for NPLMMetric_(2, 7) are: (6000,1e-08)
# (M,lam) values for NPLMMetric_(2, 8) are: (7000,1e-08)
# (M,lam) values for NPLMMetric_(2, 9) are: (8000,1e-08)
# (M,lam) values for NPLMMetric_(2, 10) are: (9000,1e-08)
# (M,lam) values for NPLMMetric_(2, 11) are: (10000,1e-08)
# (M,lam) values for NPLMMetric_(2, 12) are: (11000,1e-08)
# (M,lam) values for NPLMMetric_(2, 13) are: (12000,1e-08)
# (M,lam) values for NPLMMetric_(2, 14) are: (13000,1e-08)
# (M,lam) values for NPLMMetric_(2, 15) are: (14000,1e-08)
# (M,lam) values for NPLMMetric_(2, 16) are: (15000,1e-08)
# (M,lam) values for NPLMMetric_(2, 17) are: (16000,1e-08)
# (M,lam) values for NPLMMetric_(2, 18) are: (17000,1e-08)
# (M,lam) values for NPLMMetric_(2, 19) are: (18000,1e-08)
# (M,lam) values for NPLMMetric_(2, 20) are: (19000,1e-08)
# (M,lam) values for NPLMMetric_(2, 21) are: (20000,1e-08)
# {'NPLMMetric_(0, 0)': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdcf4c0a6d0>, 'NPLMMetric_(0, 1)': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdbe417fb10>, 'NPLMMetric_(0, 2)': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdcf0150710>, 'NPLMMetric_(0, 3)': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdcf4b58590>, 'NPLMMetric_(0, 4)': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdcf4aa5150>, 'NPLMMetric_(0, 5)': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdbb4129210>, 'NPLMMetric_(0, 6)': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdb20056ed0>, 'NPLMMetric_(0, 7)': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdcf4a80d90>, 'NPLMMetric_(0, 8)': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdb2a0f9610>, 'NPLMMetric_(0, 9)': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdbe40c6fd0>, 'NPLMMetric_(0, 10)': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdb200451d0>, 'NPLMMetric_(0, 11)': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdb2006cd90>, 'NPLMMetric_(0, 12)': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdb200c4d10>, 'NPLMMetric_(0, 13)': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdb2005df50>, 'NPLMMetric_(0, 14)': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdb200ed650>, 'NPLMMetric_(0, 15)': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdb200ed9d0>, 'NPLMMetric_(0, 16)': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdb20070bd0>, 'NPLMMetric_(0, 17)': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdb20070550>, 'NPLMMetric_(0, 18)': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdb2a1196d0>, 'NPLMMetric_(0, 19)': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdbe40e54d0>, 'NPLMMetric_(0, 20)': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdb18078890>, 'NPLMMetric_(0, 21)': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdb18078310>, 'NPLMMetric_(1, 0)': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdb200247d0>, 'NPLMMetric_(1, 1)': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdb20026d90>, 'NPLMMetric_(1, 2)': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdb20027090>, 'NPLMMetric_(1, 3)': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdb20037290>, 'NPLMMetric_(1, 4)': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdb20035a50>, 'NPLMMetric_(1, 5)': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdb20034ed0>, 'NPLMMetric_(1, 6)': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdb200e0210>, 'NPLMMetric_(1, 7)': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdb200e0090>, 'NPLMMetric_(1, 8)': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdb200e2b50>, 'NPLMMetric_(1, 9)': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdb200e2210>, 'NPLMMetric_(1, 10)': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdb200e3550>, 'NPLMMetric_(1, 11)': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdb200e0510>, 'NPLMMetric_(1, 12)': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdb200e0c50>, 'NPLMMetric_(1, 13)': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdb200e2e50>, 'NPLMMetric_(1, 14)': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdb200e3b10>, 'NPLMMetric_(1, 15)': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdb200e2910>, 'NPLMMetric_(1, 16)': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdb200e1950>, 'NPLMMetric_(1, 17)': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdb200a7c90>, 'NPLMMetric_(1, 18)': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdb200a6dd0>, 'NPLMMetric_(1, 19)': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdb200a4590>, 'NPLMMetric_(1, 20)': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdb200a4ed0>, 'NPLMMetric_(1, 21)': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdb200a43d0>, 'NPLMMetric_(2, 0)': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdb20091c50>, 'NPLMMetric_(2, 1)': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdb20092390>, 'NPLMMetric_(2, 2)': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdb20093cd0>, 'NPLMMetric_(2, 3)': <GMetrics.metrics.NPLM.NPLMMetric object at 0x7fdb20093650>, 'NPLMMetric_(2, 4)': <GMetrics.metrics. ...

# %%
name = "nplm"

file = null_hypotheses_dir + f"test_statistic_fluc_M_lam.json"

null_hp_times = np.zeros((len(lam_list), len(M_list)))
metric_values = np.zeros((len(lam_list), len(M_list), niter))

if os.path.exists(file):
    print(f"File {file} already exists. Loading existing results.")
    with open(file, "r") as f:
        results = json.load(f)
    lam_list = [lam for result in results for lam in result["lam"].keys()]
    M_list = [item["M"] for item in results[0]["lam"][lam_list[0]]]
    for i, result in enumerate(results):
        for lam, lam_data in result["lam"].items():
            for j, M_data in enumerate(lam_data):  # For each M value in the lambda
            
                null_hp_times[i, j] = M_data["computing_time"]
                metric_values[i, j] = M_data["metric_list"]
    
    for i in range(len(lam_list)):       
        for j in range(len(M_list)):
            print(f"For λ={lam_list[i]} and M = {M_list[j]}, the null hypothesis for {niter} points has been calculated in {null_hp_times[i,j]} s.")

else:
    results = []
    metric_values = np.zeros((len(lam_list), len(M_list), niter))
    null_hp_times = np.zeros((len(lam_list), len(M_list)))  

    for i in range(len(lam_list)):
        results.append({"lam": {}})
        
        for j in range(len(M_list)):
            start = timer()
            print(f"Computing and saving {name}")
            nplm_objects_M_lam[f"NPLMMetric_{i,j}"].Test_np()
            metric_values[i, j] = nplm_objects_M_lam[f"NPLMMetric_{i,j}"].test_statistics_values
            end = timer()
            
            print(f"All done in: {end - start:.2f} s.")
            null_hp_times[i, j] = end - start  
        
            if lam_list[i] not in results[i]["lam"]:
                results[i]["lam"][lam_list[i]] = [] 
            
            # Append the new data for the current M value
            results[i]["lam"][lam_list[i]].append({
                "M": M_list[j],
                "computing_time": null_hp_times[i, j],
                "metric_list": metric_values[i, j].tolist()
            })

    with open(file, "w") as file:
        json.dump(results, file, indent=4)
# Out:
# File results/20D_unimodal/20D_20K_NPLM_Par/null_hypothesis/test_statistic_fluc_M_lam.json already exists. Loading existing results.
# For λ=1e-06 and M = 500, the null hypothesis for 20 points has been calculated in 46.3472520923242 s.
# For λ=1e-06 and M = 750, the null hypothesis for 20 points has been calculated in 39.59320649318397 s.
# For λ=1e-06 and M = 1000, the null hypothesis for 20 points has been calculated in 35.0194342546165 s.
# For λ=1e-06 and M = 2000, the null hypothesis for 20 points has been calculated in 27.239005581475794 s.
# For λ=1e-06 and M = 3000, the null hypothesis for 20 points has been calculated in 25.32383367884904 s.
# For λ=1e-06 and M = 4000, the null hypothesis for 20 points has been calculated in 20.903174517676234 s.
# For λ=1e-06 and M = 5000, the null hypothesis for 20 points has been calculated in 22.220074750483036 s.
# For λ=1e-06 and M = 6000, the null hypothesis for 20 points has been calculated in 24.98064450547099 s.
# For λ=1e-06 and M = 7000, the null hypothesis for 20 points has been calculated in 28.05215898435563 s.
# For λ=1e-06 and M = 8000, the null hypothesis for 20 points has been calculated in 33.63610122445971 s.
# For λ=1e-06 and M = 9000, the null hypothesis for 20 points has been calculated in 39.79334818664938 s.
# For λ=1e-06 and M = 10000, the null hypothesis for 20 points has been calculated in 45.53132480662316 s.
# For λ=1e-06 and M = 11000, the null hypothesis for 20 points has been calculated in 52.23535992205143 s.
# For λ=1e-06 and M = 12000, the null hypothesis for 20 points has been calculated in 60.060975599102676 s.
# For λ=1e-06 and M = 13000, the null hypothesis for 20 points has been calculated in 68.79078311286867 s.
# For λ=1e-06 and M = 14000, the null hypothesis for 20 points has been calculated in 77.20728666428477 s.
# For λ=1e-06 and M = 15000, the null hypothesis for 20 points has been calculated in 84.59854488819838 s.
# For λ=1e-06 and M = 16000, the null hypothesis for 20 points has been calculated in 97.08584621548653 s.
# For λ=1e-06 and M = 17000, the null hypothesis for 20 points has been calculated in 111.6780661791563 s.
# For λ=1e-06 and M = 18000, the null hypothesis for 20 points has been calculated in 118.05308284237981 s.
# For λ=1e-06 and M = 19000, the null hypothesis for 20 points has been calculated in 129.1313663609326 s.
# For λ=1e-06 and M = 20000, the null hypothesis for 20 points has been calculated in 142.76797300577164 s.
# For λ=1e-07 and M = 500, the null hypothesis for 20 points has been calculated in 48.68816147837788 s.
# For λ=1e-07 and M = 750, the null hypothesis for 20 points has been calculated in 42.37887069582939 s.
# For λ=1e-07 and M = 1000, the null hypothesis for 20 points has been calculated in 37.153505427762866 s.
# For λ=1e-07 and M = 2000, the null hypothesis for 20 points has been calculated in 30.43727809097618 s.
# For λ=1e-07 and M = 3000, the null hypothesis for 20 points has been calculated in 30.763727230019867 s.
# For λ=1e-07 and M = 4000, the null hypothesis for 20 points has been calculated in 31.262452440336347 s.
# For λ=1e-07 and M = 5000, the null hypothesis for 20 points has been calculated in 32.85350986011326 s.
# For λ=1e-07 and M = 6000, the null hypothesis for 20 points has been calculated in 36.22984178736806 s.
# For λ=1e-07 and M = 7000, the null hypothesis for 20 points has been calculated in 41.53345938026905 s.
# For λ=1e-07 and M = 8000, the null hypothesis for 20 points has been calculated in 49.04306386131793 s.
# For λ=1e-07 and M = 9000, the null hypothesis for 20 points has been calculated in 54.87142899259925 s.
# For λ=1e-07 and M = 10000, the null hypothesis for 20 points has been calculated in 62.43488581106067 s.
# For λ=1e-07 and M = 11000, the null hypothesis for 20 points has been calculated in 70.8799153380096 s.
# For λ=1e-07 and M = 12000, the null hypothesis for 20 points has been calculated in 75.66012427583337 s.
# For λ=1e-07 and M = 13000, the null hypothesis for 20 points has been calculated in 85.92280166596174 s.
# For λ=1e-07 and M = 14000, the null hypothesis for 20 points has been calculated in 95.40539828781039 s.
# For λ=1e-07 and M = 15000, the null hypothesis for 20 points has been calculated in 104.53166350722313 s.
# For λ=1e-07 and M = 16000, the null hypothesis for 20 points has been calculated in 119.27477616537362 s.
# For λ=1e-07 and M = 17000, the null hypothesis for 20 points has been calculated in 130.75651306379586 s.
# For λ=1e-07 and M = 18000, the null hypothesis for 20 points has been calculated in 138.38491741847247 s.
# For λ=1e-07 and M = 19000, the null hypothesis for 20 points has been calculated in 155.37990354839712 s.
# For λ=1e-07 and M = 20000, the null hypothesis for 20 points has been calculated in 167.0025544082746 s.
# For λ=1e-08 and M = 500, the null hypothesis for 20 points has been calculated in 71.04197167232633 s.
# For λ=1e-08 and M = 750, the null hypothesis for 20 points has been calculated in 69.87982754036784 s.
# For λ=1e-08 and M = 1000, the null hypothesis for 20 points has been calculated in 68.277642859146 s.
# For λ=1e-08 and M = 2000, the null hypothesis for 20 points has been calculated in 55.61891864892095 s.
# For λ=1e-08 and M = 3000, the null hypothesis for 20 points has been calculated in 53.45520225726068 s.
# For λ=1e-08 and M = 4000, the null hypothesis for 20 points has been calculated in 55.792320581153035 s.
# For λ=1e-08 and M = 5000, the null hypothesis for 20 points has been calculated in 59.452893055044115 s.
# For λ=1e-08 and M = 6000, the null hypothesis for 20 points has been calculated in 64.57935727853328 s.
# For λ=1e-08 and M = 7000, the null hypothesis for 20 points has been calculated in 71.20565375033766 s.
# For λ=1e-08 and M = 8000, the null hypothesis for 20 points has been calculated in 82.22234523668885 s.
# For λ=1e-08 and M = 9000, the null hypothesis for 20 points has been calculated in 78.8300248850137 s.
# For λ=1e-08 and M = 10000, the null hypothesis for 20 points has been calculated in 83.32919262815267 s.
# For λ=1e-08 and M = 11000, the null hypothesis for 20 points has been calculated in 93.66672589350492 s.
# For λ=1e-08 and M = 12000, the null hypothesis for 20 points has been calculated in 104.32047990243882 s.
# For λ=1e-08 and M = 13000, the null hypothesis for 20 points has been calculated in 116.53240495268255 s.
# For λ=1e-08 and M = 14000, the null hypothesis for 20 points has been calculated in 129.79252354893833 s.
# For λ=1e-08 and M = 15000, the null hypothesis for 20 points has been calculated in 140.74995468743145 s.
# For λ=1e-08 and M = 16000, the null hypothesis for 20 points has been calculated in 160.40312246978283 s.
# For λ=1e-08 and M = 17000, the null hypothesis for 20 points has been calculated in 170.3590072374791 s.
# For λ=1e-08 and M = 18000, the null hypothesis for 20 points has been calculated in 185.78560070041567 s.
# For λ=1e-08 and M = 19000, the null hypothesis for 20 points has been calculated in 202.50022348295897 s.
# For λ=1e-08 and M = 20000, the null hypothesis for 20 points has been calculated in 214.53215243667364 s.

# %%
file = null_hypotheses_dir + f"test_statistic_fluc_M_lam.json"

null_hp_times = np.zeros((len(lam_list), len(M_list)))
metric_values = np.zeros((len(lam_list), len(M_list), niter))

if os.path.exists(file):
    print(f"File {file} already exists. Loading existing results.")
    with open(file, "r") as f:
        results = json.load(f)
    lam_list = [lam for result in results for lam in result["lam"].keys()]
    lam_list = np.array(lam_list)
    M_list = [item["M"] for item in results[0]["lam"][lam_list[0]]]
    for i, result in enumerate(results):
        for lam, lam_data in result["lam"].items():
            for j, M_data in enumerate(lam_data):  # For each M value in the lambda
            
                null_hp_times[i, j] = M_data["computing_time"]
                metric_values[i, j] = M_data["metric_list"]
                null_hp_times = np.array(null_hp_times)
                metric_values = np.array(metric_values)
                
else:
    print("file does not exist")
    

color_list = ['b','r','g']
label_list = [f'λ={lam}' for lam in lam_list]


plt.figure(figsize=(11, 6))
for i in range(len(lam_list)):
    plt.errorbar(M_list, null_hp_times[i]/niter,  capsize=5 ,marker='o', linestyle='-', color = color_list[i], label = label_list[i])

plt.xlabel("M", fontsize=14)
plt.ylabel("Computing time per point (s)", fontsize=14)
plt.title(f"M vs. Computing time per point (s), ({niter} points considered for H_0)", fontsize=16)
plt.grid(True, which="both", linestyle="--", linewidth=0.5)
plt.tight_layout()
plt.legend()

plt.savefig(null_hypotheses_dir+"Computing_time_vs_M.pdf", format="pdf")
plt.show()
# Out:
# File results/20D_unimodal/20D_20K_NPLM_Par/null_hypothesis/test_statistic_fluc_M_lam.json already exists. Loading existing results.

# %%
file = null_hypotheses_dir + f"test_statistic_fluc_M_lam.json"

null_hp_times = np.zeros((len(lam_list), len(M_list)))
metric_values = np.zeros((len(lam_list), len(M_list), niter))

if os.path.exists(file):
    print(f"File {file} already exists. Loading existing results.")
    with open(file, "r") as f:
        results = json.load(f)
    lam_list = [lam for result in results for lam in result["lam"].keys()]
    lam_list = np.array(lam_list)
    M_list = [item["M"] for item in results[0]["lam"][lam_list[0]]]
    for i, result in enumerate(results):
        for lam, lam_data in result["lam"].items():
            for j, M_data in enumerate(lam_data):  # For each M value in the lambda
            
                null_hp_times[i, j] = M_data["computing_time"]
                metric_values[i, j] = M_data["metric_list"]
                null_hp_times = np.array(null_hp_times)
                metric_values = np.array(metric_values)
                
else:
    print("file does not exist")
    

color_list = ['b','r','g']
label_list = [f'λ={lam}' for lam in lam_list]

avg_test_stat = np.zeros((len(lam_list), len(M_list)))
std_test_stat = np.zeros((len(lam_list), len(M_list)))

for i, lam in enumerate(lam_list):
    for j, m in enumerate(M_list):
        avg_test_stat[i,j] = (np.mean(metric_values[i,j]))
        std_test_stat[i,j] = (np.std(metric_values[i,j]))
    print(f"Average test statistic values for lambda = {lam} varying M: {avg_test_stat[i]}\n"
          f" with std: {std_test_stat[i]}")

plt.figure(figsize=(11, 6))
for i in range(len(lam_list)):
    plt.errorbar(M_list, avg_test_stat[i], std_test_stat[i], capsize=5 ,marker='o', linestyle='-', color = color_list[i], label = label_list[i])

plt.xlabel("M", fontsize=14)
plt.ylabel("Mean Test Statistic Value", fontsize=14)
plt.title(f"M vs. Mean Test Statistic Value, ({niter} points considered for H_0)", fontsize=16)
plt.grid(True, which="both", linestyle="--", linewidth=0.5)
plt.tight_layout()
plt.legend()

plt.savefig(null_hypotheses_dir+"Test_statistic_fluc_vs_M.pdf", format="pdf")
plt.show()
# Out:
# File results/20D_unimodal/20D_20K_NPLM_Par/null_hypothesis/test_statistic_fluc_M_lam.json already exists. Loading existing results.
# Average test statistic values for lambda = 1e-06 varying M: [449.64048603 485.17691313 500.67502853 519.73641991 523.73460698
#  525.28463449 526.0502544  526.46110616 526.7369888  526.85694936
#  526.86424852 526.85398085 526.8217249  526.82566226 526.84167371
#  526.89479025 526.93815514 526.96033855 526.98343875 526.99645447
#  527.0050232  527.01284736]
#  with std: [32.69427216 34.3628283  34.09649549 34.21906257 34.27977484 34.26658378
#  34.2721561  34.28677138 34.24758488 34.24906465 34.25077605 34.25266086
#  34.25551045 34.27189689 34.28761982 34.28759766 34.2784088  34.27386536
#  34.28055557 34.27551393 34.27411442 34.27241836]
# Average test statistic values for lambda = 1e-07 varying M: [ 814.27934528  958.96922174 1038.02438274 1155.48657796 1184.77287399
#  1196.69317949 1202.49897245 1205.4942564  1207.16262902 1208.1979055
#  1208.88729154 1209.41809745 1209.84476047 1210.12740478 1210.35753822
#  1210.55073369 1210.696807   1210.8225801  1210.89865607 1210.97482631
#  1211.05394497 1211.09312931]
#  with std: [46.95797528 53.66301579 53.95056471 53.51250914 53.66333932 53.51009416
#  53.47256614 53.41448207 53.43126699 53.42001408 53.42853738 53.42085693
#  53.42687257 53.39463527 53.43573414 53.42402738 53.41367327 53.40343729
#  53.40065084 53.38538574 53.37368431 53.3826626 ]
# Average test statistic values for lambda = 1e-08 varying M: [1012.63586746 1391.09216861 1682.427657   2223.19212363 2388.63872755
#  2465.37658011 2505.47881604 2527.23554371 2540.06971664 2548.26937138
#  2553.82333219 2557.74846611 2560.64841946 2562.67083386 2564.24854385
#  2565.49082848 2566.45397196 2567.17267096 2567.78874474 2568.29299011
#  2568.70331275 2569.06420622]
#  with std: [61.33321896 74.99583949 82.78318279 81.57018908 82.53860066 82.29371841
#  82.45607108 82.49449217 82.49393642 82.45194502 82.32398215 82.3139637
#  82.29975945 82.25893395 82.26083717 82.18490166 82.19078078 82.1943819
#  82.18084682 82.15390968 82.1803322  82.12902292]
